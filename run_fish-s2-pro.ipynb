# %%
#@title Install fish-s2-pro
root_path = "/teamspace/studios/this_studio" # @param ['/content', '/root', '/kaggle/working','/teamspace/studios/this_studio']
# %cd $root_path
# !rm -rf $root_path/fish-speech-colab
# !git clone https://github.com/NeuralFalconYT/fish-speech-colab.git
# %cd $root_path/fish-speech-colab
# !pip install huggingface-hub
from hf_mirror import download_model
download_model(
    "fishaudio/s2-pro",
    download_folder="./model",
    redownload=True,
    workers=6,
    use_snapshot=True,  
)

download_model(
    "deepdml/faster-whisper-large-v3-turbo-ct2",
    download_folder="./faster-whisper-large-v3-turbo-ct2",
    redownload=True,
    workers=6,
    use_snapshot=True,  
)
# !git clone https://github.com/fishaudio/fish-speech.git
# !apt-get update
# !apt-get install -y portaudio19-dev
# !pip install pyaudio
# !pip install -r requirements.txt

from IPython.display import clear_output
import time
time.sleep(5)
import os
os.kill(os.getpid(), 9)

# %%
root_path = '/teamspace/studios/this_studio' # @param ['/content', '/root', '/kaggle/working','/teamspace/studios/this_studio']
# %cd $root_path/fish-speech-colab
# !python app.py --share --debug
# Out:
# /teamspace/studios/this_studio/fish-speech-colab
# 2026-03-11 17:56:33.041 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:503 - Injected Semantic IDs into Config: 151678-155773
# ...
